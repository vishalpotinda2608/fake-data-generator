# %%
import pandas as pd

# %%
df=pd.read_csv('npcitxns.csv')

# %%
df.shape
# Out:
# (200000, 25)

# %%
df.head()
# Out:
#   NPCI_TXN_TYPE NPCI_STATUS                                 TXNID  \
# 0            TX          U2  4196229f-e2fc-40b2-9741-f1e74877da6e
# 1            TX          U2  dde90a3b-dcd9-4463-8b34-5a5c333b816b
# 2            TX          U2  88421374-d7ac-410f-9649-6a5599916add
# 3            TX          U2  18cda22f-00cb-47f7-ade6-8d152b5b7613
# 4            TX          U2  eb9043e9-c539-4a11-99e4-7651dc643a76
#
#             RRN NPCI_CODE   DATE    TIME  AMOUNT  \
# 0  227019681200        Z9  40124  210230  393.77
# 1  542934099761        RB  40124  210230  451.45
# 2  784118475675        Z9  40124  210230  969.58
# 3   16658177755        Z9  40124  210230  315.27
# 4    3356301692        00  40124  210230  500.29
#
#                                       A  B  ...    F           PAYEE_VPA  \
# 0  cb9274e72eb6406fba57211045db5fa5@axl  1  ...  COB    Nya_Feeney@yahoo
# 1  cb9274e72eb6406fba57211045db5fa5@axl  1  ...  COB  Mavis.Senger@gmail
# ...
