# %%
import pandas as pd

# %%
df=pd.read_csv('npcitxns.csv')

# %%
df.shape
# Out:
# (500000, 25)

# %%
df.head()
# Out:
#   NPCI_TXN_TYPE NPCI_STATUS                     TXNID           RRN NPCI_CODE  \
# 0            TX          U2  acd4bf6bc8b9045feb9eaf1a  638386246099        Z9
# 1            TX          U2  f67f7e3bac12df3c72ae8b67  462581399622        Z9
# 2            TX          U2  d5d38cda31dd427a454ecff4  681411347661        RB
# 3            TX          U2  25e491ccd1c3f6ecdb2a7bcc  165965113537        Z9
# 4            TX          U2  dfffb4c7ec1f9d6ae715c2fb  868419032664        Z9
#
#     DATE    TIME  AMOUNT                                     A  B  ...    F  \
# 0  40424  210230  430.32  cb9274e72eb6406fba57211045db5fa5@axl  1  ...  COB
# 1  40424  210230  961.38  cb9274e72eb6406fba57211045db5fa5@axl  1  ...  COB
# 2  40424  210230  562.65  cb9274e72eb6406fba57211045db5fa5@axl  1  ...  COB
# 3  40424  210230  602.66  cb9274e72eb6406fba57211045db5fa5@axl  1  ...  COB
# 4  40424  210230   67.46  cb9274e72eb6406fba57211045db5fa5@axl  1  ...  COB
#
# ...
